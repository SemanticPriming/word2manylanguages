# %%
import glob
import matplotlib.pyplot as plt
import matplotlib
import matplotlib as mpl
import numpy as np
import os
import pandas as pd
import sys
from IPython.display import display

basedir = os.path.join('Y:\\', 'Dissertation')

# Reference and appendices for datasets
basedir = os.path.join('Y:\\', 'Dissertation')
vpdatadir = os.path.join(basedir, 'workspace','subs2vec', 'subs2vec', 'datasets', 'norms')
countdatadir = os.path.join(basedir, 'frequencies')
datasetsdir = os.path.join(basedir, 'datasets')

codepath = os.path.join(basedir, 'workspace', 'word2manylanguages', 'python')
sys.path.append(codepath)
import word2manylanguages as wm

# %%
from IPython.core.display import HTML
# van Paridon and Thompson datasets
files = glob.glob(vpdatadir + "\\*.tsv")
rows = []

for file in files:
    pathparts = file.split("\\")
    filename = pathparts[len(pathparts) - 1][0: file.index('.tsv')]
    parts = filename.split('-')
    language = parts[0]
    year = parts[len(parts) - 1].split('.')[0]
    name = ''
    for i in range(1,len(parts) - 1):
        name += parts[i] + ' '
        
    dataset = f'{name} ({year})'
    row = dict()
    row["Dataset"] = dataset
    row["Language"] = wm.code2lang[language]
    
    norms = pd.read_csv(file,sep='\t', comment='#',na_values=['-','–'])
    # Get the columns that hold the norms
    found = ''
    for col in norms.columns:
        if not col == 'word':
            found += col + ', '
                
     
    row["Norms"] = found[:len(found)-2]
    row["Words"] = len(norms)
    
    rows.append(row)
    
dataframe = pd.DataFrame(rows)   
dataframe.sort_values(by=['Dataset'], ascending=[True], inplace=True)
#display(dataframe)
display(HTML(dataframe.to_html(index=False, justify='left')))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Dataset</th>
#       <th>Language</th>
#       <th>Norms</th>
#       <th>Words</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>bakhtiar  (2015)</td>
#       <td>farsi</td>
#       <td>age of acquisition, familiarity, imageability</td>
#       <td>871</td>
#     </tr>
#     <tr>
#       <td>binder  (2016)</td>
#       <td>english</td>
#       <td>mean r, vision, bright, dark, color, pattern, large, small, motion, biomotion, fast, slow, shape, complexity, face, body, touch, temperature, texture, weight, pain, audition, loud, low, high, sound, music, speech, taste, smell, head, upperlimb, lowerlimb, practice, landmark, path, scene, near, toward, away, number, time, duration, long, short, caused, consequential, social, human, communication, self, cognition, benefit, harm, pleasant, unpleasant, happy, sad, angry, disgusted, fearful, surprised, drive, needs, attention, arousal, word length, word frequency, word log10 frequency</td>
#       <td>535</td>
#     </tr>
#     <tr>
#       <td>bonin  (2018)</td>
#       <td>french</td>
#       <td>concreteness, context availability, valence, arousal</td>
#       <td>1659</td>
#     </tr>
#     <tr>
#       <td>brysbaert  (2014)</td>
#       <td>dutch</td>
#       <td>age of acquisition, concreteness</td>
#       <td>25888</td>
#     </tr>
#     <tr>
#       <td>brysbaert  (2014)</td>
#       <td>english</td>
#       <td>concreteness</td>
#       <td>37058</td>
#     </tr>
#     <tr>
#       <td>brysbaert  (2019)</td>
#       <td>english</td>
#       <td>prevalence</td>
#       <td>61855</td>
#     </tr>
#     <tr>
#       <td>cameirao  (2010)</td>
#       <td>portuguese</td>
#       <td>age of acquisition</td>
#       <td>1749</td>
#     </tr>
#     <tr>
#       <td>chedid  (2019a)</td>
#       <td>french</td>
#       <td>familiarity</td>
#       <td>3596</td>
#     </tr>
#     <tr>
#       <td>chedid  (2019b)</td>
#       <td>french</td>
#       <td>visual perceptual strength, auditory perceptual strength</td>
#       <td>3596</td>
#     </tr>
#     <tr>
#       <td>desrochers  (2009)</td>
#       <td>french</td>
#       <td>imageability</td>
#       <td>3600</td>
#     </tr>
#     <tr>
#       <td>diez alamo  (2018)</td>
#       <td>spanish</td>
#       <td>color vividness, visual motion, graspability, risk of pain, sound intensity, pleasant taste, smell intensity</td>
#       <td>750</td>
#     </tr>
#     <tr>
#       <td>diez alamo  (2019)</td>
#       <td>spanish</td>
#       <td>sensory experience</td>
#       <td>5500</td>
#     </tr>
#     <tr>
#       <td>eilola  (2010)</td>
#       <td>finnish</td>
#       <td>familiarity, valence, emotional charge, offensiveness, concreteness</td>
#       <td>210</td>
#     </tr>
#     <tr>
#       <td>engelthaler  (2018)</td>
#       <td>english</td>
#       <td>humorousness</td>
#       <td>4997</td>
#     </tr>
#     <tr>
#       <td>ferrand  (2010)</td>
#       <td>french</td>
#       <td>lexical decision time</td>
#       <td>38335</td>
#     </tr>
#     <tr>
#       <td>goz  (2017)</td>
#       <td>turkish</td>
#       <td>age of acquisition, imagery, concreteness</td>
#       <td>600</td>
#     </tr>
#     <tr>
#       <td>grandy  (2020)</td>
#       <td>german</td>
#       <td>imageability (young adults), imageability (older adults), emotionality (young adults), emotionality (older adults)</td>
#       <td>2592</td>
#     </tr>
#     <tr>
#       <td>guasch  (2016)</td>
#       <td>spanish</td>
#       <td>valence, arousal, concreteness, imageability, context availability, familiarity</td>
#       <td>1400</td>
#     </tr>
#     <tr>
#       <td>imbir  (2016)</td>
#       <td>polish</td>
#       <td>valence, arousal, dominance, concreteness, imageability, age of acquisition</td>
#       <td>4905</td>
#     </tr>
#     <tr>
#       <td>janschewitz  (2008)</td>
#       <td>english</td>
#       <td>familiarity, tabooness, personal use, offensiveness</td>
#       <td>460</td>
#     </tr>
#     <tr>
#       <td>kanske  (2010)</td>
#       <td>german</td>
#       <td>valence, arousal, concreteness</td>
#       <td>1000</td>
#     </tr>
#     <tr>
#       <td>keuleers  (2012)</td>
#       <td>english</td>
#       <td>lexical decision time</td>
#       <td>28515</td>
#     </tr>
#     <tr>
#       <td>keuleers  (2015)</td>
#       <td>dutch</td>
#       <td>prevalence</td>
#       <td>54319</td>
#     </tr>
#     <tr>
#       <td>kuperman  (2012)</td>
#       <td>english</td>
#       <td>age of acquisition</td>
#       <td>31124</td>
#     </tr>
#     <tr>
#       <td>lynott  (2019)</td>
#       <td>english</td>
#       <td>auditory, gustatory, haptic, interoceptive, olfactory, visual, foot and leg, hand and arm, head, mouth, torso, perceptual exclusivity, action exclusivity, sensorimotor exclusivity</td>
#       <td>39707</td>
#     </tr>
#     <tr>
#       <td>monnier  (2014)</td>
#       <td>french</td>
#       <td>arousal, valence</td>
#       <td>1031</td>
#     </tr>
#     <tr>
#       <td>pexman  (2019)</td>
#       <td>english</td>
#       <td>body object interaction</td>
#       <td>9349</td>
#     </tr>
#     <tr>
#       <td>roest  (2018)</td>
#       <td>dutch</td>
#       <td>arousal, valence, taboo (general), taboo (personal), insulting</td>
#       <td>672</td>
#     </tr>
#     <tr>
#       <td>san miguel abella  (2019)</td>
#       <td>spanish</td>
#       <td>motor content, age of acquisition</td>
#       <td>4565</td>
#     </tr>
#     <tr>
#       <td>schauenburg  (2015)</td>
#       <td>german</td>
#       <td>potency, authority, community, arousal, valence</td>
#       <td>858</td>
#     </tr>
#     <tr>
#       <td>scott  (2019)</td>
#       <td>english</td>
#       <td>arousal, valence, dominance, concreteness, imageability, familiarity, age of acquisition, semantic size, gender association</td>
#       <td>5553</td>
#     </tr>
#     <tr>
#       <td>sianipar  (2016)</td>
#       <td>indonesian</td>
#       <td>valence, arousal, dominance, predicability, concreteness</td>
#       <td>1490</td>
#     </tr>
#     <tr>
#       <td>soares  (2012)</td>
#       <td>portuguese</td>
#       <td>valence, arousal, dominance</td>
#       <td>1034</td>
#     </tr>
#     <tr>
#       <td>soderholm  (2013)</td>
#       <td>finnish</td>
#       <td>arousal, valence</td>
#       <td>420</td>
#     </tr>
#     <tr>
#       <td>speed  (2017)</td>
#       <td>dutch</td>
#       <td>auditory, gustatory, olfactory, tactile, visual, modality exclusivity, arousal, dominance, valence</td>
#       <td>485</td>
#     </tr>
#     <tr>
#       <td>stadthagen gonzalez  (2017)</td>
#       <td>spanish</td>
#       <td>valence, arousal</td>
#       <td>14031</td>
#     </tr>
#     <tr>
#       <td>stadthagen gonzalez  (2018)</td>
#       <td>spanish</td>
#       <td>happiness, disgust, anger, fear, sadness, valence, arousal</td>
#       <td>10491</td>
#     </tr>
#     <tr>
#       <td>vergallito  (2020)</td>
#       <td>italian</td>
#       <td>lexical decision time, naming time, auditory, gustatory, haptic, olfactory, visual, modality exclusivity</td>
#       <td>1121</td>
#     </tr>
#     <tr>
#       <td>verheyen  (2019)</td>
#       <td>dutch</td>
#       <td>age of acquisition, arousal, concreteness, dominance, familiarity, imageability, valence</td>
#       <td>1000</td>
#     </tr>
#     <tr>
#       <td>warriner  (2013)</td>
#       <td>english</td>
#       <td>valence, arousal, dominance</td>
#       <td>13915</td>
#     </tr>
#     <tr>
#       <td>yap  (2010)</td>
#       <td>maylay</td>
#       <td>lexical decision time</td>
#       <td>1510</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Frequecy datasets
files = glob.glob(countdatadir + "\\*.tsv")
rows = []

for file in files:
    pathparts = file.split("\\")
    filename = pathparts[len(pathparts) - 1][0: file.index('.tsv')]
    
    dataset = 'Wikipedia' if 'wiki' in filename else 'OpenSubtitles'
    language = filename[6:8]
    
    row = dict()
    row["Dataset"] = dataset
    row["Language"] = wm.code2lang[language]
    
    freqs = pd.read_csv(file,sep='\t',header=0)
    
    row["Words"] = len(freqs)
    
    rows.append(row)
    
dataframe = pd.DataFrame(rows)   
dataframe.sort_values(by=['Language', 'Dataset'], ascending=[True, True], inplace=True)
#display(dataframe)
display(HTML(dataframe.to_html(index=False, justify='left')))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Dataset</th>
#       <th>Language</th>
#       <th>Words</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>afrikaans</td>
#       <td>18348</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>afrikaans</td>
#       <td>472483</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>albanian</td>
#       <td>268784</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>albanian</td>
#       <td>678017</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>arabic</td>
#       <td>2948365</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>arabic</td>
#       <td>2777714</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>armenian</td>
#       <td>6842</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>armenian</td>
#       <td>1587461</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>basque</td>
#       <td>154490</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>basque</td>
#       <td>912341</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>bengali</td>
#       <td>71529</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>bengali</td>
#       <td>582451</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>bosnian</td>
#       <td>1234974</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>bosnian</td>
#       <td>599375</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>breton</td>
#       <td>7897</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>breton</td>
#       <td>294420</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>bulgarian</td>
#       <td>1634739</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>bulgarian</td>
#       <td>1095857</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>catalan</td>
#       <td>76707</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>catalan</td>
#       <td>1719956</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>croatian</td>
#       <td>1921586</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>croatian</td>
#       <td>1411258</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>czech</td>
#       <td>2229819</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>czech</td>
#       <td>2267282</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>danish</td>
#       <td>725688</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>danish</td>
#       <td>1321603</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>dutch</td>
#       <td>1157937</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>dutch</td>
#       <td>3150670</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>english</td>
#       <td>2397981</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>english</td>
#       <td>17647386</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>esperanto</td>
#       <td>37631</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>esperanto</td>
#       <td>1238526</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>estonian</td>
#       <td>1075882</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>estonian</td>
#       <td>1534733</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>farsi</td>
#       <td>793173</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>farsi</td>
#       <td>1791801</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>finnish</td>
#       <td>2556993</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>finnish</td>
#       <td>3299720</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>french</td>
#       <td>939750</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>french</td>
#       <td>4955659</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>galacian</td>
#       <td>85531</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>galacian</td>
#       <td>721396</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>georgian</td>
#       <td>96397</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>georgian</td>
#       <td>891101</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>german</td>
#       <td>1026035</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>german</td>
#       <td>10890665</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>greek</td>
#       <td>1980845</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>greek</td>
#       <td>1253137</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>hebrew</td>
#       <td>1745644</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>hebrew</td>
#       <td>1918506</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>hindi</td>
#       <td>20659</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>hindi</td>
#       <td>534124</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>hungarian</td>
#       <td>3331866</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>hungarian</td>
#       <td>3531117</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>icelandic</td>
#       <td>268453</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>icelandic</td>
#       <td>403646</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>indonesian</td>
#       <td>494717</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>indonesian</td>
#       <td>1500683</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>italian</td>
#       <td>958113</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>italian</td>
#       <td>3220952</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>kazakh</td>
#       <td>4770</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>kazakh</td>
#       <td>996627</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>korean</td>
#       <td>749169</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>korean</td>
#       <td>5942895</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>latvian</td>
#       <td>152266</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>latvian</td>
#       <td>589725</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>lithuanian</td>
#       <td>329039</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>lithuanian</td>
#       <td>981210</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>macedonian</td>
#       <td>365474</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>macedonian</td>
#       <td>769456</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>malayalam</td>
#       <td>202177</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>malayalam</td>
#       <td>1224293</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>maylay</td>
#       <td>148820</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>maylay</td>
#       <td>737965</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>norwegian</td>
#       <td>551727</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>norwegian</td>
#       <td>1975605</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>polish</td>
#       <td>2036319</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>polish</td>
#       <td>3590954</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>portuguese</td>
#       <td>835479</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>portuguese</td>
#       <td>2357801</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>romanian</td>
#       <td>1644295</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>romanian</td>
#       <td>1266845</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>russian</td>
#       <td>1599368</td>
#     </tr>
#     <tr>
#       <td>Wikipedia</td>
#       <td>russian</td>
#       <td>5683285</td>
#     </tr>
#     <tr>
#       <td>OpenSubtitles</td>
#       <td>serbian</td>
#       <td>2994063</td>
#     </tr>
#     <tr>
#       <td>Wikipe

# %%
# Additional datasets
files = glob.glob(datasetsdir + "\\*.csv")
rows = []

for file in files:
    pathparts = file.split("\\")
    dataset = pathparts[len(pathparts) - 1].split('.')[0]
    
    
    row = dict()
    row["Dataset"] = dataset
    
    try:
        norms = pd.read_csv(file,sep=',', comment='#',na_values=['-','–'])
        # Get the columns that hold the norms
        cols = wm.list_norm_columns(norms)
    
        langs = []
        for col in norms.columns:
            if col.startswith('word_'):
                 langs += [col[5:]]
        row["Language"] = langs[0]           
     
    
        found = ''
        for col in cols:
            found += col + ', '
            row["Norms"] = found[:len(found)-2]
            
        
        
        row["Words"] = len(norms)
    except:
        row["Language"] = 'unknown'           
     
        row["Norms"] = 'None'
        row["Words"] = 0
    
    rows.append(row)
    
dataframe = pd.DataFrame(rows)   
dataframe.sort_values(by=['Dataset'], ascending=[True], inplace=True)
#display(dataframe)
display(HTML(dataframe.to_html(index=False, justify='left')))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Dataset</th>
#       <th>Language</th>
#       <th>Norms</th>
#       <th>Words</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Alario1999</td>
#       <td>spanish</td>
#       <td>image_agreement_M, familiar_M, complexity_M, variability_M, aoa_M</td>
#       <td>400</td>
#     </tr>
#     <tr>
#       <td>Alonso2015</td>
#       <td>spanish</td>
#       <td>aoa_M, oral_freq_log_M, written_freq_log_SUBTLEXESP_M, written_freq_log_LEXESP_M, written_freq_log_espal_M</td>
#       <td>7039</td>
#     </tr>
#     <tr>
#       <td>Alonso2016</td>
#       <td>spanish</td>
#       <td>aoa_M</td>
#       <td>4640</td>
#     </tr>
#     <tr>
#       <td>Altarriba1999</td>
#       <td>english</td>
#       <td>concrete_M, contextavailability_M, imagine_M</td>
#       <td>326</td>
#     </tr>
#     <tr>
#       <td>Alvarez2007</td>
#       <td>spanish</td>
#       <td>aoa_M</td>
#       <td>328</td>
#     </tr>
#     <tr>
#       <td>Amsel2012</td>
#       <td>english</td>
#       <td>familiar_M, pain_M, smell_M, color_M, taste_M, sound_M, grasp_M, motion_M</td>
#       <td>559</td>
#     </tr>
#     <tr>
#       <td>Bakhtiar2013</td>
#       <td>persian</td>
#       <td>imageagree_M, familiar_M, visualcomplex_M, aoa_M, imageability_M</td>
#       <td>200</td>
#     </tr>
#     <tr>
#       <td>Barbarotto2005</td>
#       <td>italian</td>
#       <td>aoa_o_M</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <td>Bestgen2012</td>
#       <td>english</td>
#       <td>arousal_LSA_M, arousal_norms_M, concrete_LSA_M, concrete_norms_M, dominate_LSA_M, dominate_norms_M, imagine_LSA_M, imagine_norms_M, valence_LSA_M, valence_norms_M</td>
#       <td>17350</td>
#     </tr>
#     <tr>
#       <td>Birchenough2017</td>
#       <td>german</td>
#       <td>aoa_M, aoa_M_likert</td>
#       <td>3259</td>
#     </tr>
#     <tr>
#       <td>Bonin2003</td>
#       <td>french</td>
#       <td>naming_time_ms_M, image_agreement_M, familiar_M, visual_complexity_M, image_variability_M, aoa_M</td>
#       <td>299</td>
#     </tr>
#     <tr>
#       <td>Bonin2013a</td>
#       <td>french</td>
#       <td>valence_M, arousal_M, contextavailability_M, concrete_M</td>
#       <td>1659</td>
#     </tr>
#     <tr>
#       <td>Bonin2015</td>
#       <td>english_acronym</td>
#       <td>aoa_M, subjective_frequency_M, imagine_M, bigram_frequency_M</td>
#       <td>321</td>
#     </tr>
#     <tr>
#       <td>Bonin2015a</td>
#       <td>french</td>
#       <td>sensory_M</td>
#       <td>1659</td>
#     </tr>
#     <tr>
#       <td>Bonin2021</td>
#       <td>french</td>
#       <td>aoa_M, familiar_M, imagine_M</td>
#       <td>506</td>
#     </tr>
#     <tr>
#       <td>Boukadi2016</td>
#       <td>english</td>
#       <td>name_agreement_M, familiar_M, frequency_M, imagine_M</td>
#       <td>400</td>
#     </tr>
#     <tr>
#       <td>Briesemeister2011</td>
#       <td>german_upper</td>
#       <td>happy_M, anger_M, sad_M, fear_M, disgust_M</td>
#       <td>1958</td>
#     </tr>
#     <tr>
#       <td>Brysbaert2014</td>
#       <td>english</td>
#       <td>concrete_M</td>
#       <td>39954</td>
#     </tr>
#     <tr>
#       <td>Cameirao2010</td>
#       <td>portuguese</td>
#       <td>familiar_M, concrete_M, image_M, aoa_M</td>
#       <td>1749</td>
#     </tr>
#     <tr>
#       <td>Cannard2008</td>
#       <td>french</td>
#       <td>aoa_M, aoa_M_Chalard2003, aoa_M_Pind2000, aoa_M_Morrison1997, aoa_M_Barbarotto2005, aoa_M_Pérez2005, aoa_M_Alvarez2007</td>
#       <td>145</td>
#     </tr>
#     <tr>
#       <td>Chiarello1999</td>
#       <td>english</td>
#       <td>imagine_M, imagine_M_RT, familiar_M</td>
#       <td>1196</td>
#     </tr>
#     <tr>
#       <td>Clark2004</td>
#       <td>english</td>
#       <td>aoa_M, concrete_M, familiar_M, imagine_M, intense_M, valence_M</td>
#       <td>925</td>
#     </tr>
#     <tr>
#       <td>Cohen-Shikora2013</td>
#       <td>english</td>
#       <td>imagine_M, RT_M</td>
#       <td>2201</td>
#     </tr>
#     <tr>
#       <td>Cordier2005</td>
#       <td>french</td>
#       <td>meaning_knowledge_M, familiar_M</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <td>Cortese2004</td>
#       <td>english</td>
#       <td>rt_M, imagine_M</td>
#       <td>3000</td>
#     </tr>
#     <tr>
#       <td>Cortese2008</td>
#       <td>english</td>
#       <td>aoa_s_M, rt_M</td>
#       <td>3000</td>
#     </tr>
#     <tr>
#       <td>Cuetos2003</td>
#       <td>spanish</td>
#       <td>imagine_M, familiar_M, aoa_M, visual_complexity_M</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <td>DellaRosa2010</td>
#       <td>italian</td>
#       <td>concrete_M, imagine_M, familiar_M, aoa_M</td>
#       <td>417</td>
#     </tr>
#     <tr>
#       <td>Desrochers2009</td>
#       <td>french</td>
#       <td>frequency_M, imagine_M</td>
#       <td>3600</td>
#     </tr>
#     <tr>
#       <td>Diez-Alamo2018</td>
#       <td>spanish</td>
#       <td>aoa_M</td>
#       <td>5500</td>
#     </tr>
#     <tr>
#       <td>Dimitripoulou2009</td>
#       <td>greek</td>
#       <td>aoa_s_M</td>
#       <td>268</td>
#     </tr>
#     <tr>
#       <td>Eilola2010</td>
#       <td>unknown</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Elsherif2020</td>
#       <td>english</td>
#       <td>frequency_M_log, familiar_M_American, familiar_M_British, imagine_M_British, aoa_M_log, imagine_M_American, transparency_M, Lexeme_Meaning_Dominance_M, Length_first_lexeme_M, Frequency_first_lexeme_M, familiar_M_first_lexeme, aoa_M_log_first_lexeme, imagine_M_first_lexeme, length_second_lexeme_M, frequency_second_lexeme_M, familiar_M_second_lexeme, aoa_M_log_second_lexeme, imagine_M_second_lexeme</td>
#       <td>226</td>
#     </tr>
#     <tr>
#       <td>Ferrand2008</td>
#       <td>french</td>
#       <td>aoa_M, frequency_M</td>
#       <td>1493</td>
#     </tr>
#     <tr>
#       <td>Ferre2012</td>
#       <td>spanish</td>
#       <td>valence_M, arousal_M, familiar_M, concrete_M, frequency_M</td>
#       <td>380</td>
#     </tr>
#     <tr>
#       <td>Ferre2017</td>
#       <td>spanish</td>
#       <td>happy_M, angry_M, sad_M, fear_M, disgust_M</td>
#       <td>2266</td>
#     </tr>
#     <tr>
#       <td>Ferstl2011</td>
#       <td>english</td>
#       <td>valence_M</td>
#       <td>305</td>
#     </tr>
#     <tr>
#       <td>Ghasisin2015</td>
#       <td>persian</td>
#       <td>H_M_middle_age, H_M_elderly, familiar_M_middle_age, familiar_M_elderly, aoa_M_middle_age, aoa_M_elderly, visualcomplex_M_middle_age, visualcomplex_M_elderly</td>
#       <td>272</td>
#     </tr>
#     <tr>
#       <td>Grigoriev2013</td>
#       <td>english</td>
#       <td>aoa_o_M_months, imageagree_M, imagine_M, familiar_M</td>
#       <td>288</td>
#     </tr>
#     <tr>
#       <td>Gruhn2008a</td>
#       <td>german</td>
#       <td>valence_M_young_female, valence_M_young_male, valence_M_old_female, valence_M_old_male, valence_M_young, valence_M_old, valence_M, arousal_M_young_female, arousal_M_young_male, arousal_M_old_female, arousal_M_old_male, arousal_M_young, arousal_M_old, arousal_M, control_M_young_female, control_M_young_male, control_M_old_female, control_M_old_male, control_M_young, control_M_old, control_M, imagine_M_young_female, imagine_M_young_male, imagine_M_old_female, imagine_M_old_male, imagine_M_young, imagine_M_old, imagine_M, selfrelevance_M_young_female, selfrelevance_M_young_male, selfrelevance_M_old_female, selfrelevance_M_old_male, selfrelevance_M_young, selfrelevance_M_old, selfrelevance_M, agerelevance_M_young_female, agerelevance_M_young_male, agerelevance_M_old_female, agerelevance_M_old_male, agerelevance_M_young, agerelevance_M_old, agerelevance_M, valence_M_self, valence_M_other, self_or_other_M</td>
#       <td>202</td>
#     </tr>
#     <tr>
#       <td>Gruhn2008b</td>
#       <td>unknown</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Guasch2016</td>
#       <td>spanish</td>
#       <td>valence_M, arousal_M, concrete_M, imagine_M, availability_M, familiar_M</td>
#       <td>1400</td>
#     </tr>
#     <tr>
#       <td>Hao2008_infant</td>
#       <td>type</td>
#       <td>NaN</td>
#       <td>464</td>
#     </tr>
#     <tr>
#       <td>Hao2008_toddler</td>
#       <td>type</td>
#       <td>NaN</td>
#       <td>710</td>
#     </tr>
#     <tr>
#       <td>Imbir2015</td>
#       <td>polish</td>
#       <td>valence_M, valence_M_female, valence_
